# %%
import pandas as pd

import seaborn as sns
from wordcloud import WordCloud

# %%
df = pd.read_csv('filteredRecords2.csv')
df.head()
# Out:
#                                                 text label
# 0  scandal use arnsworth castle business married ...     A
# 1  bed two clock may call really hard day work da...     A
# 2  worked muscles developed well snuff freemasonr...     A
# 3  rather shamefaced laugh shillings plentiful re...     A
# 4  slice beef joint upon sideboard sandwiched two...     A

# %%
wc = WordCloud(width = 800, height = 300, background_color ='white',  max_words=1500)
text = ' '.join(list(df.text[df.label =='A']))
plt.figure(figsize = (12, 7), facecolor = None) 
plt.axis("off")
plt.tight_layout(pad = 0) 
plt.imshow(wc.generate(text))

# %%
wc = WordCloud(width = 800, height = 300, background_color ='white',  max_words=1500)
text = ' '.join(list(df.text[df.label =='B']))
plt.figure(figsize = (12, 7), facecolor = None) 
plt.axis("off")
plt.tight_layout(pad = 0) 
plt.imshow(wc.generate(text))

# %%
wc = WordCloud(width = 800, height = 300, background_color ='white',  max_words=1500)
text = ' '.join(list(df.text[df.label =='C']))
plt.figure(figsize = (12, 7), facecolor = None) 
plt.axis("off")
plt.tight_layout(pad = 0) 
plt.imshow(wc.generate(text))

# %%
wc = WordCloud(width = 800, height = 300, background_color ='white',  max_words=1500)
text = ' '.join(list(df.text[df.label =='D']))
plt.figure(figsize = (12, 7), facecolor = None) 
plt.axis("off")
plt.tight_layout(pad = 0) 
plt.imshow(wc.generate(text))

# %%
wc = WordCloud(width = 800, height = 300, background_color ='white',  max_words=1500)
text = ' '.join(list(df.text[df.label =='E']))
plt.figure(figsize = (12, 7), facecolor = None) 
plt.axis("off")
plt.tight_layout(pad = 0) 
plt.imshow(wc.generate(text))
